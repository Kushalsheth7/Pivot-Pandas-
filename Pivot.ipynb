# %%
import pandas as pd


data = {
    'Product': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Region': ['North', 'North', 'North', 'South', 'South', 'South'],
    'Sales': [100, 200, 150, 300, 400, 350]
}

df = pd.DataFrame(data)
print(df)


pivot_df = df.pivot(index='Region', columns='Product', values='Sales')

print(pivot_df)
# Out:
#   Product Region  Sales
# 0       A  North    100
# 1       B  North    200
# 2       C  North    150
# 3       A  South    300
# 4       B  South    400
# 5       C  South    350
# Product    A    B    C
# Region
# North    100  200  150
# South    300  400  350

# %%
data = {
    'Product': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
    'Region': ['North', 'North', 'North', 'South', 'South', 'South', 'East', 'East', 'East'],
    'Sales': [100, 200, 150, 300, 400, 350, 500, 600, 550]
}

df = pd.DataFrame(data)
print(df)


pivot_table_df = df.pivot_table(values='Sales', index='Region', columns='Product', aggfunc='sum', fill_value=0)

print(pivot_table_df)
# Out:
#   Product Region  Sales
# 0       A  North    100
# 1       B  North    200
# 2       C  North    150
# 3       A  South    300
# 4       B  South    400
# 5       C  South    350
# 6       A   East    500
# 7       B   East    600
# 8       C   East    550
# Product    A    B    C
# Region
# East     500  600  550
# North    100  200  150
# South    300  400  350

# %%
data = {
    'Product': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
    'Region': ['North', 'North', 'North', 'South', 'South', 'South', 'East', 'East', 'East'],
    'Sales': [100, 200, 150, 300, 400, 350, 500, 600, 550],
    'Profit': [10, 20, 15, 30, 40, 35, 50, 60, 55]
}

df = pd.DataFrame(data)
print(df)

pivot_table_df = df.pivot_table(values=['Sales', 'Profit'], index='Region', columns='Product', aggfunc={'Sales': 'sum', 'Profit': 'mean'}, fill_value=0)

print(pivot_table_df)
# Out:
#   Product Region  Sales  Profit
# 0       A  North    100      10
# 1       B  North    200      20
# 2       C  North    150      15
# 3       A  South    300      30
# 4       B  South    400      40
# 5       C  South    350      35
# 6       A   East    500      50
# 7       B   East    600      60
# 8       C   East    550      55
#         Profit             Sales
# Product      A     B     C     A    B    C
# Region
# East      50.0  60.0  55.0   500  600  550
# North     10.0  20.0  15.0   100  200  150
# South     30.0  40.0  35.0   300  400  350

# %%
import pandas as pd

data=pd.read_csv('Walmart_Sales.csv')
data
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
pivot_df = data.pivot(index='Store', columns='Date', values='Weekly_Sales')

print(pivot_df)
# Out:
# Date   01-04-2011  01-06-2012  01-07-2011  01-10-2010  02-03-2012  02-04-2010  \
# Store
# 1      1495064.75  1624477.58  1488538.09  1453329.50  1688420.76  1594968.28
# 2      1800171.36  1910092.37  1866243.00  1827440.43  1952555.66  2066187.72
# 3       374556.08   432268.53   368962.72   358784.10   469752.56   423294.40
# 4      1900246.47  2179360.94  2051533.53  1842821.02  2206319.90  1979247.12
# 5       314316.55   359867.80   327093.89   283178.12   359206.21   331406.00
# 6      1459276.77  1681121.38  1694551.15  1328468.89  1550385.65  1770333.90
# 7       513409.67   598495.02   704344.21   448998.73   551058.13   561145.14
# 8       878762.30   921161.20   883683.35   804105.49   952264.91   914500.91
# 9       520962.14   583648.59   537064.03   495692.19   619498.28   545206.32
# 10     1827733.18  1767471.48  1751369.75  1645892.97  1990371.02  2138651.97
# 11     1258674.12  1361595.33  1297472.06  1182490.46  1438383.44  1446210.26
# ...
